# %%
# Importing libraries # 
import pandas as pd
import numpy as np
import os

# Setting working directory # 
#os.getcwd()
new_directory = 'C:/Users/AD09332/OneDrive - DNB Bank ASA/Dokumenter/VS Code/VS Code Workspace/Course files/Intermediate Programming/Capstone-near-earth-objects/NEO'
os.chdir(new_directory)
pd.set_option('display.max_columns', None)

# %%
neo = pd.read_csv('data/neos.csv')
import json
with open("data/cad.json", "r") as infile:
    cad = json.load(infile)
# Out:
# C:\Users\AD09332\AppData\Local\Temp\ipykernel_44308\2408983979.py:1: DtypeWarning: Columns (4,5,16,23,24,70) have mixed types. Specify dtype option on import or set low_memory=False.
#   neo = pd.read_csv('data/neos.csv')

# %%
neo[["pdes", "name", "pha", "diameter"]]
# Out:
#             pdes      name  pha  diameter
# 0            433      Eros    N    16.840
# 1            719    Albert    N       NaN
# 2            887    Alinda    N     4.200
# 3           1036   Ganymed    N    37.675
# 4           1221      Amor    N     1.000
# ...          ...       ...  ...       ...
# 23962  2019 Y4-D     ATLAS  NaN       NaN
# 23963    2020 G1  Pimentel  NaN       NaN
# 23964    2020 M3     ATLAS  NaN       NaN
# 23965  2020 P4-B       NaN  NaN       NaN
# 23966  2020 P4-C       NaN  NaN       NaN
#
# [23967 rows x 4 columns]

# %%
neo.name.value_counts()
# Out:
# Schwassmann-Wachmann    68
# SOHO                    10
# LINEAR                   9
# Machholz                 4
# LONEOS                   3
#                         ..
# Sekhmet                  1
# Jasonwheeler             1
# Melissabrucker           1
# Camarillo                1
# Pimentel                 1
# Name: name, Length: 240, dtype: int64

# %%
#neo.query('name == " "').
neo.name.info() #only 343 of the NEOs have IAU names
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 23967 entries, 0 to 23966
# Series name: name
# Non-Null Count  Dtype
# --------------  -----
# 343 non-null    object
# dtypes: object(1)
# memory usage: 187.4+ KB

# %%
neo.diameter.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 23967 entries, 0 to 23966
# Series name: diameter
# Non-Null Count  Dtype
# --------------  -----
# 1268 non-null   float64
# dtypes: float64(1)
# memory usage: 187.4 KB

# %%
neo.head()
# Out:
#          id    spkid                 full_name  pdes     name prefix neo pha  \
# 0  a0000433  2000433        433 Eros (A898 PA)   433     Eros    NaN   Y   N
# 1  a0000719  2000719      719 Albert (A911 TB)   719   Albert    NaN   Y   N
# 2  a0000887  2000887      887 Alinda (A918 AA)   887   Alinda    NaN   Y   N
# 3  a0001036  2001036    1036 Ganymed (A924 UB)  1036  Ganymed    NaN   Y   N
# 4  a0001221  2001221      1221 Amor (1932 EA1)  1221     Amor    NaN   Y   N
#
#       H     G  M1  M2  K1  K2  PC  diameter          extent  albedo  rot_per  \
# 0  10.4  0.46 NaN NaN NaN NaN NaN    16.840  34.4x11.2x11.2   0.250    5.270
# 1  15.5   NaN NaN NaN NaN NaN NaN       NaN             NaN     NaN    5.801
# 2  13.8 -0.12 NaN NaN NaN NaN NaN     4.200             NaN   0.310   73.970
# 3   9.4  0.30 NaN NaN NaN NaN NaN    37.675             NaN   0.238   10.297
# 4  17.7   NaN NaN NaN NaN NaN NaN     1.000             NaN     NaN      NaN
#
# ...

# %%
#cad

# %%
cad['data'][1][3]
# Out:
# '1900-Jan-01 02:33'

# %%
print(cad['fields'])
for i in range(406785):
    if '2000-Jan-01' in cad['data'][i][3]:
        print(cad['data'][i])
# Out:
# ['des', 'orbit_id', 'jd', 'cd', 'dist', 'dist_min', 'dist_max', 'v_rel', 'v_inf', 't_sigma_f', 'h']
# ['2015 CL', '7', '2451544.575085225', '2000-Jan-01 01:48', '0.144929602021186', '0.144894711605919', '0.144964493657327', '12.0338907050642', '12.0323628689746', '00:19', '25.3']
# ['2002 PB', '22', '2451544.656861311', '2000-Jan-01 03:46', '0.499221505520251', '0.499198890779505', '0.499244120869353', '29.3862908945476', '29.3861092695424', '< 00:01', '20.5']
# ['417655', '32', '2451544.967962443', '2000-Jan-01 11:14', '0.347809805138266', '0.347809185789178', '0.347810424487433', '9.63652182082792', '9.63572681897425', '< 00:01', '19.9']
# ['2002 AY1', '47', '2451545.232240258', '2000-Jan-01 17:34', '0.271330274354689', '0.271330198605043', '0.271330350105786', '24.6801874471394', '24.6797895515273', '< 00:01', '20.8']

# %%
neo.head()
# Out:
#          id    spkid                 full_name  pdes     name prefix neo pha  \
# 0  a0000433  2000433        433 Eros (A898 PA)   433     Eros    NaN   Y   N
# 1  a0000719  2000719      719 Albert (A911 TB)   719   Albert    NaN   Y   N
# 2  a0000887  2000887      887 Alinda (A918 AA)   887   Alinda    NaN   Y   N
# 3  a0001036  2001036    1036 Ganymed (A924 UB)  1036  Ganymed    NaN   Y   N
# 4  a0001221  2001221      1221 Amor (1932 EA1)  1221     Amor    NaN   Y   N
#
#       H     G  M1  M2  K1  K2  PC  diameter          extent  albedo  rot_per  \
# 0  10.4  0.46 NaN NaN NaN NaN NaN    16.840  34.4x11.2x11.2   0.250    5.270
# 1  15.5   NaN NaN NaN NaN NaN NaN       NaN             NaN     NaN    5.801
# 2  13.8 -0.12 NaN NaN NaN NaN NaN     4.200             NaN   0.310   73.970
# 3   9.4  0.30 NaN NaN NaN NaN NaN    37.675             NaN   0.238   10.297
# 4  17.7   NaN NaN NaN NaN NaN NaN     1.000             NaN     NaN      NaN
#
# ...

# %%
# Out:
# 0    [des, orbit_id, jd, cd, dist, dist_min, dist_m...
# Name: fields, dtype: object
